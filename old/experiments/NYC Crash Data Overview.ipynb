# %%
import pandas as pd
import pandas_profiling

# %%
crashes = pd.read_csv('../data/NYC_Motor_Vehicle_Collisions_-_Crashes.csv', low_memory=False)

# %%
crashes.head()
# Out:
#    CRASH DATE CRASH TIME BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  11/05/2012      22:00     NaN      NaN        NaN        NaN
# 1  12/16/2015      16:40     NaN      NaN        NaN        NaN
# 2  07/08/2015      21:05     NaN      NaN        NaN        NaN
# 3  10/20/2014      16:50     NaN      NaN        NaN        NaN
# 4  11/05/2012       4:40     NaN      NaN  40.664941 -73.996636
#
#                     LOCATION                    ON STREET NAME  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN  BRUCKNER BOULEVARD
# 4  (40.6649411, -73.9966365)                               NaN
#
#                   CROSS STREET NAME                           OFF STREET NAME  \
# 0                               NaN  NYHQ EMERGENCY RAMP N/O BOOTH MEMORIAL A
# ...

# %%
crashes.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.513694e+06  1.513694e+06               1.719097e+06
# mean   4.069000e+01 -7.386726e+01               2.692338e-01
# std    1.181295e+00  2.395893e+00               6.650900e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066871e+01 -7.397633e+01               0.000000e+00
# 50%    4.072231e+01 -7.392876e+01               0.000000e+00
# 75%    4.076859e+01 -7.386669e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.719083e+06                   1.719114e+06
# mean               1.226817e-03                   5.108155e-02
# std                3.705490e-02                   2.325906e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# ...

# %%
pd.to_datetime(crashes['CRASH DATE']).describe()
# Out:
# count                 1719114
# unique                   3020
# top       2014-01-21 00:00:00
# freq                     1161
# first     2012-07-01 00:00:00
# last      2020-10-06 00:00:00
# Name: CRASH DATE, dtype: object

# %%
profile = pandas_profiling.ProfileReport(crashes)

# %%
profile.to_widgets()
