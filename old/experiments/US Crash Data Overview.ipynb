# %%
import pandas as pd
import pandas_profiling

# %%
crashes = pd.read_csv('../data/US_Accidents_June20.tar.gz', low_memory=False)

# %%
crashes.head()
# Out:
#   US_Accidents_June20.csv    Source    TMC  Severity           Start_Time  \
# 0                     A-1  MapQuest  201.0       3.0  2016-02-08 05:46:00
# 1                     A-2  MapQuest  201.0       2.0  2016-02-08 06:07:59
# 2                     A-3  MapQuest  201.0       2.0  2016-02-08 06:49:27
# 3                     A-4  MapQuest  201.0       3.0  2016-02-08 07:23:34
# 4                     A-5  MapQuest  201.0       2.0  2016-02-08 07:39:07
#
#               End_Time  Start_Lat  Start_Lng  End_Lat  End_Lng  ...  \
# 0  2016-02-08 11:00:00  39.865147 -84.058723      NaN      NaN  ...
# 1  2016-02-08 06:37:59  39.928059 -82.831184      NaN      NaN  ...
# 2  2016-02-08 07:19:27  39.063148 -84.032608      NaN      NaN  ...
# 3  2016-02-08 07:53:34  39.747753 -84.205582      NaN      NaN  ...
# 4  2016-02-08 08:09:07  39.627781 -84.188354      NaN      NaN  ...
#
#    Roundabout Station   Stop Traffic_Calming Traffic_Signal Turning_Loop  \
# ...

# %%
crashes.describe()
# Out:
#                 TMC      Severity     Start_Lat     Start_Lng       End_Lat  \
# count  2.478818e+06  3.513740e+06  3.513740e+06  3.513740e+06  1.034922e+06
# mean   2.080226e+02  2.339935e+00  3.654208e+01 -9.579208e+01  3.755791e+01
# std    2.076627e+01  5.522103e-01  4.883511e+00  1.736894e+01  4.861103e+00
# min    2.000000e+02  1.000000e+00  2.455527e+01 -1.246238e+02  2.457011e+01
# 25%    2.010000e+02  2.000000e+00  3.363793e+01 -1.174420e+02  3.399487e+01
# 50%    2.010000e+02  2.000000e+00  3.591703e+01 -9.102632e+01  3.779787e+01
# 75%    2.010000e+02  3.000000e+00  4.032258e+01 -8.093303e+01  4.105139e+01
# max    4.060000e+02  4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01
#
#             End_Lng  Distance(mi)        Number  Temperature(F)  \
# count  1.034922e+06  3.513740e+06  1.250786e+06    3.448004e+06
# mean  -1.004574e+02  2.816462e-01  5.975823e+03    6.193496e+01
# std    1.852878e+01  1.550166e+00  1.496662e+04    1.862108e+01
# ...

# %%
profile = pandas_profiling.ProfileReport(crashes)

# %%
# Generate Summary Statistics Report (takes a few minutes)
# profile.to_widgets()

# %% [markdown]
# ## Demonstrate ability to collect all crashes in a city or county

# %%
county = "Arlington"
state = "VA"

arlington_crashes = crashes[(crashes['State']==state) & (crashes['County']==county)]
arlington_crashes[['US_Accidents_June20.csv', 'Start_Time', 'Start_Lat', 'State', 'County', 
                   'Temperature(F)', 'Weather_Condition']].head()
# Out:
#        US_Accidents_June20.csv           Start_Time  Start_Lat State  \
# 228597                A-228599  2016-11-30 19:09:27  38.846519    VA
# 228667                A-228669  2016-12-01 07:04:26  38.862434    VA
# 228675                A-228677  2016-12-01 07:09:35  38.846519    VA
# 228699                A-228701  2016-12-01 07:59:00  38.874119    VA
# 228807                A-228809  2016-12-01 16:47:29  38.864910    VA
#
#            County  Temperature(F) Weather_Condition
# 228597  Arlington            62.1          Overcast
# 228667  Arlington            53.1     Partly Cloudy
# 228675  Arlington            53.1     Partly Cloudy
# 228699  Arlington            53.1     Partly Cloudy
# 228807  Arlington            51.1     Partly Cloudy

# %%
city = "Richmond"
state = "VA"

arlington_crashes = crashes[(crashes['State']==state) & (crashes['City']==city)]
arlington_crashes[['US_Accidents_June20.csv', 'Start_Time', 'Start_Lat', 'State', 'City', 
                   'Temperature(F)', 'Weather_Condition']].head()
# Out:
#        US_Accidents_June20.csv           Start_Time  Start_Lat State  \
# 512295                A-512301  2020-05-24 17:22:59  37.611858    VA
# 512769                A-512775  2020-05-25 17:17:43  37.518490    VA
# 512776                A-512782  2020-05-25 20:29:01  37.617260    VA
# 513935                A-513941  2020-05-26 08:02:45  37.513401    VA
# 513936                A-513942  2020-05-26 08:02:45  37.519230    VA
#
#             City  Temperature(F) Weather_Condition
# 512295  Richmond            68.0            Cloudy
# 512769  Richmond            75.0     Mostly Cloudy
# 512776  Richmond            66.0              Fair
# 513935  Richmond            61.0               Fog
# 513936  Richmond            61.0               Fog
